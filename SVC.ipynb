# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.svm import SVC

# %%
X1,y1 = make_classification(n_samples=10000,n_features=2,n_redundant =0,n_informative=2, n_clusters_per_class=1,class_sep=2.0,random_state=42)

# %% [markdown]
# X

# %%
X1
# Out:
# array([[-0.79523968,  0.64233456],
#        [-2.38119698,  2.39004105],
#        [ 1.56435067,  1.46732012],
#        ...,
#        [ 1.71780349,  1.41191702],
#        [-1.99091527,  1.76611131],
#        [ 1.76910002,  1.95719755]])

# %%
y1
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
X1.shape
# Out:
# (10000, 2)

# %%
y1.shape
# Out:
# (10000,)

# %%
plt.scatter(X1[:,0],X1[:,1],c=y1)
plt.show()

# %%
from sklearn.datasets import make_blobs
X2,y2=make_blobs(n_samples=10000,centers=2,n_features=2,random_state=32)
plt.scatter(X2[:,0],X2[:,1],c=y2)
plt.show()

# %%
from sklearn.datasets import make_moons
X3,y3=make_moons(n_samples=10000, noise =0,random_state=32)
plt.scatter(X3[:,0],X3[:,1],c=y3)
plt.show()

# %%
from sklearn.datasets import make_moons
X3,y3=make_moons(n_samples=10000, noise =0.3,random_state=32)
plt.scatter(X3[:,0],X3[:,1],c=y3)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X1,y1,test_size=.30,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((7000, 2), (3000, 2))

# %%
from sklearn.svm import LinearSVC
clf=LinearSVC()
clf.fit(X_train,y_train)
# Out:
# LinearSVC()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.997

# %%
clf.score(X_train,y_train)
# Out:
# 0.9961428571428571

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3,y3,test_size=.30,random_state=42)

# %%
clf.fit(X_train3,y_train3)
# Out:
# LinearSVC()

# %%
y_pred3 = clf.predict(X_test3)

# %%
accuracy_score(y_test3,y_pred3)
# Out:
# 0.8416666666666667

# %%
clf.score(X_train3,y_train3)
# Out:
# 0.8507142857142858
